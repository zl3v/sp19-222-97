# %%
import matplotlib.pyplot as plt
import csv

with open('./data/MOCK_DATA.csv') as csv_file:
    entries = []
    csv_reader = csv.reader(csv_file, delimiter=',')
    line_count = 0
    for row in csv_reader:
        if line_count == 0:
            # print(f'Column names are {", ".join(row)}')
            line_count += 1
        else:
            # print(f'\tName: {row[0]} Score: {row[1]} Level: {row[2]}')
            new_entry = {row[0], row[1], row[2]}
            entries.append(new_entry)
            line_count += 1

# %%
print(entries)
# Out:
# [{'Tonie', '5', '71641'}, {'2', '79619', 'Lorette'}, {'Zonda', '36446', '1'}, {'99987', 'Fancy', '1'}, {'3', 'Alvan', '33628'}, {'4', '19324', 'Maren'}, {'7473', 'Elsworth', '1'}, {'57227', 'Melinda', '1'}, {'Keefer', '5', '87232'}, {'Benedick', '64854', '5'}, {'Candide', '61375', '1'}, {'2', 'Aretha', '74782'}, {'Giffer', '1', '89548'}, {'3', 'Raphaela', '96050'}, {'Filmer', '61601', '5'}, {'22065', '5', 'Dredi'}, {'2', 'Shurlock', '91937'}, {'4', 'Chucho', '23116'}, {'4', '43364', 'Chadwick'}, {'Callida', '57440', '1'}, {'3', 'Stu', '34341'}, {'Leigha', '95388', '1'}, {'2', '23456', 'Ailyn'}, {'Kaycee', '4', '83137'}, {'2', 'Cliff', '10026'}, {'1', 'Minna', '21258'}, {'3', '94359', 'Albrecht'}, {'1', 'Colly', '30662'}, {'5', 'Lari', '34059'}, {'2', '34728', 'Lem'}, {'2', '96177', 'Rosemarie'}, {'16548', '4', 'Janeva'}, {'16089', '3', 'Birgit'}, {'19479', 'Jarib', '1'}, {'5', 'Zolly', '6082'}, {'85888', '4', 'Quinn'}, {'50617', 'Jacklin', '2'}, {'Burke', '3', '16764'}, {'4', '43751', 'Valencia'}, {'Skelly', '11335', '1'}, {'2', '89012', 'Jacintha'}, {'15526', '5', 'Franciskus'}, {'Alfy', '26866', '2'}, {'4', '94212', 'Harlene'}, {'Filmore', '1', '7837'}, {'Lammond', '3', '41661'}, {'2', 'Edeline', '60007'}, {'5', '35306', 'Garnette'}, {'2', 'Wallache', '64576'}, {'2', '13832', 'Osbourn'}, {'Theressa', '1', '71903'}, {'2', 'Deidre', '58295'}, {'2', '82617', 'Val'}, {'4', '59077', 'Joyan'}, {'Thea', '18828', '2'}, {'2', 'Devinne', '64721'}, {'70217', '1', 'Zak'}, {'Ortensia', '3', '40134'}, {'2', '15398', 'Haroun'}, {'5', 'Garvey', '90851'}, {'Kathie', '1', '4589'}, {'Diena', '5', '70199'}, {'2', 'Loren', '73700'}, {'2', '73440', 'Ody'}, {'41663', '1', 'Tedie'}, {'2', 'Tybalt', '36970'}, {'3', '76828', 'Dory'}, {'Frederica', '5', '68629'}, {'3', 'Boycey', '75753'}, {'2', 'Maxi', '48077'}, {'Shirline', '41566', '1'}, {'15343', '5', 'Gil'}, {'5', '16131', 'Jarred'}, {'80538', 'Mendy', '2'}, {'4', '62038', 'Chrysler'}, {'Karlens', '68239', '1'}, {'23586', 'Mariann', '5'}, {'14416', '5', 'Malva'}, {'5', '62436', 'Aloin'}, {'2', 'Jillane', '56185'}, {'3', '15118', 'Nanice'}, {'Vanya', '97910', '1'}, {'Peyter', '98096', '3'}, {'54147', 'Isak', '1'}, {'Merralee', '52741', '1'}, {'88222', 'Perri', '1'}, {'Roscoe', '13254', '1'}, {'3', 'Archer', '80806'}, {'2', '96788', 'Felicdad'}, {'Harper', '3', '66699'}, {'73012', 'Ginni', '1'}, {'Kareem', '60548', '5'}, {'Isadora', '39041', '5'}, {'4', '84820', 'Raffaello'}, {'92090', '5', 'Major'}, {'6249', 'Lyell', '5'}, {'Randolf', '38679', '1'}, {'2', '58157', 'Mildrid'}, {'Karlik', '66521', '2'}, {'3', 'Sarge', '91584'}, {'Doralin', '3', '28495'}, {'4', '80610', 'Lavena'}, {'Cassie', '1', '39978'}, {'3', 'Annette', '50382'}, {'Ashely', '81313', '3'}, {'4', 'Liza', '46833'}, {'2', '37941', 'Trey'}, {'53177', 'Teirtza', '1'}, {'2', 'Lilli', '22864'}, {'Hyacinthe', '1', '71372'}, {'3', 'Jennine', '70918'}, {'Pedro', '59046', '2'}, {'Marrilee', '4', '88006'}, {'Rupert', '5', '13456'}, {'2', 'Lucretia', '90149'}, {'45655', 'Mireielle', '5'}, {'5', '48371', 'Caitrin'}, {'3', '90192', 'Berenice'}, {'99793', 'Friedrich', '2'}, {'18092', 'Sharlene', '4'}, {'2', 'Hayyim', '29260'}, {'Carol', '42333', '1'}, {'52497', 'Carlo', '4'}, {'Florentia', '39786', '5'}, {'27039', 'Elisabeth', '3'}, {'63335', 'Murray', '2'}, {'Shelton', '4', '398'}, {'2', 'Dulsea', '50370'}, {'Rudolph', '64438', '3'}, {'Debbi', '5', '79728'}, {'2', 'Chickie', '84881'}, {'Sosanna', '1', '70695'}, {'Andriana', '50588', '5'}, {'Giselbert', '5', '41892'}, {'2', 'Gretchen', '23575'}, {'2', '1252', 'Yvette'}, {'3', '34004', 'Fitz'}, {'2', 'Dewey', '64985'}, {'75762', '1', 'Susanna'}, {'Shandeigh', '1304', '1'}, {'3', 'Louise', '46632'}, {'50260', '2', 'Josefina'}, {'26090', 'Jania', '4'}, {'14891', 'Bartie', '5'}, {'2', 'Bria', '62712'}, {'1623', 'Waneta', '1'}, {'Teressa', '49628', '4'}, {'Andres', '23123', '1'}, {'3', 'Renata', '26283'}, {'2', '76192', 'Vergil'}, {'28511', '5', 'Hally'}, {'Bethina', '13333', '2'}, {'4', 'Helen-elizabet ...
